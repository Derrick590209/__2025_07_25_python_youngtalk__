# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick590209/__2025_07_25_python_youngtalk__/blob/main/Lesson4/lesson_try_except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  print(10/0)
except:
  print("程式結束")
# Out:
# 程式結束

# %%
try:
  age = int(input("請輸入年紀:"))
  print(f"你輸入的年紀是{age}歲")
except:
  print(f"輸入的年紀錯誤")
# Out:
# 請輸入年紀:2.3
# 輸入的年紀錯誤

# %%
try:
  num = int(input("輸入數字"))
  print(num)

except Exception as a:
  print(f"錯誤內容:{a}")

print("程式結束")
# Out:
# 輸入數字12.3
# 錯誤內容:invalid literal for int() with base 10: '12.3'
# 程式結束
