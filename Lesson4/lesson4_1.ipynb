# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick590209/__2025_07_25_python_youngtalk__/blob/main/Lesson4/lesson4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
heigh = float(input("請輸入您的身高:"))
weigh = float(input("請輸入您的體重:"))
bmi =  weigh / (heigh/100)**2
print(f"您的身高為{heigh}公分,體重為{weigh}公斤,BMI為:{bmi:.2f}")
# Out:
# 請輸入您的身高:175.5
# 請輸入您的體重:73
# 您的身高為175.5公分,體中為73.0公斤,BMI為:23.70

# %%
# 學生總分為300
# 要檢查學生輸入的分數,是否是0~300
# 有些學生可以加分5%
# 學生分數加分後,不可以超過300

scores = int(input("請輸入學生分數(最高300分):"))
if scores >=0 and scores <=300:
  is_add = input("學生是否符合加分條件(y,n)")

  # 巢狀判斷 處理兩個條件
  if is_add == "y":
    scores *=1.05
    if scores > 300:
      scores = 300

  print(round(scores))
else:
  print("輸入的範圍,必需在0~300之間")

print("應用程式結束")
# Out:
# 請輸入學生分數(最高300分):290
# 學生是否符合加分條件(y,n)y
# 300
# 應用程式結束

# %%
money = input("請輸入金額")
# Out:
# 請輸入金額100

# %%
try:
  raise TypeError
except:
  print("出錯了")

print("應用程式結束")
# Out:
# 出錯了
# 應用程式結束

# %%
try:
  raise TypeError
except TypeError:#任何錯誤
  print("資料類型出錯了")

print("應用程式結束")
# Out:
# 資料類型出錯了
# 應用程式結束

# %%
try:
  raise ValueError
except TypeError: #指定錯誤
  print("資料類型出錯了")
except ValueError: #指定錯誤
  print("值出錯了")
except:
  print("出錯了")

print("應用程式結束")
# Out:
# 值出錯了
# 應用程式結束

# %%
try:
  raise NameError


except TypeError: #指定錯誤
  print("資料類型出錯了")
except ValueError: #指定錯誤
  print("值出錯了")
except:
  print("出錯了")

print("應用程式結束")
# Out:
# 出錯了
# 應用程式結束

# %% [markdown]
# - 可以多個except程式區塊
# - except程式區塊  只執行一個後  跳出try_except
# - except(所有錯誤, 一定要放在最後面)

# %%
try:
  raise NameError
except:
  print("出錯了")

except TypeError: #指定錯誤
  print("資料類型出錯了")
except ValueError: #指定錯誤
  print("值出錯了")


print("應用程式結束")
# Out:
#   File "/tmp/ipykernel_3367/582690770.py", line 3
#     except:
#     ^
# SyntaxError: default 'except:' must be last

# %%
try:
  #money = int(input("請輸入金額"))
  raise Exception("您停太久了,給你錯誤") #自訂錯誤 並加上錯誤說明

except TypeError: #指定錯誤
  print("資料類型出錯了")
except ValueError: #指定錯誤
  print("值出錯了")
except Exception as e:# 所有錯誤
  print(f"出錯了:{e}")

print("應用程式結束")
# Out:
# 出錯了:您停太久了,給你錯誤
# 應用程式結束

# %%
try:
  money = int(input("請輸入金額"))
  #raise Exception("您停太久了,給你錯誤") #自訂錯誤 並加上錯誤說明

except TypeError: #指定錯誤
  print("資料類型出錯了")
except ValueError: #指定錯誤
  print("值出錯了")
except Exception as e:# 所有錯誤
  print(f"出錯了:{e}")

else:
  print(f"您輸入的金額是{money}")

finally:
  print("應用程式結束")
# Out:
# 請輸入金額1000
# 您輸入的金額是1000
# 應用程式結束

# %%
# 學生總分為300
# 要檢查學生輸入的分數,是否是0~300
# 有些學生可以加分5%
# 學生分數加分後,不可以超過300

try:
  scores = int(input("請輸入學生分數(最高300分):"))
  if scores >=0 and scores <=300:
    is_add = input("學生是否符合加分條件(y,n)")

    # 巢狀判斷 處理兩個條件
    if is_add == "y":
      scores *=1.05
      if scores > 300:
        scores = 300

    print(round(scores))
  else:
    raise Exception("輸入的範圍,必需在0~300之間")

  print("應用程式結束")
except ValueError:
  print("輸入的內容有誤")
except Exception as e:
  print(f"出錯了:{e}")
print("應用程式有誤")
# Out:
# 請輸入學生分數(最高300分):302
# 出錯了:輸入的範圍,必需在0~300之間
# 應用程式有誤
