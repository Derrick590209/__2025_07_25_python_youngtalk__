# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick590209/__2025_07_25_python_youngtalk__/blob/main/lesson1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello!Python!")
# Out:
# Hello!Python!

# %%
print("Hello!東認青少年")
# Out:
# Hello!東認青少年
