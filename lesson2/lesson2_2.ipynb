# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick590209/__2025_07_25_python_youngtalk__/blob/main/lesson2/lesson2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 數學運算

# %%
top = 5
bottom = 10
height = 2
area = (top + bottom) * height / 2
print("上底:", top)
print("下底:", bottom)
print("高:", height)
print("梯形的面積:", area)
# Out:
# 上底: 5
# 下底: 10
# 高: 2
# 梯形的面積: 15.0

# %% [markdown]
# ###資料轉型

# %%
int("13")
int(float("13.5"))
# Out:
# 13

# %%
value = int(float(input("請輸入一個數值")))
print("您輸入的數值是:", value)
# Out:
# 請輸入一個數值13.5
# 您輸入的數值是: 13

# %%
top = float(input("請輸入上底:"))
bottom = float(input("請輸入下底:"))
height = float(input("請輸入下高:"))
area = (top + bottom) * height / 2

print("\n=====答案是======\n")
print("上底:", top)
print("下底:", bottom)
print("高:", height)
print("梯形的面積:", area)
# Out:
# 請輸入上底:10
# 請輸入下底:15
# 請輸入下高:2
#
# =====答案是======
#
# 上底: 10.0
# 下底: 15.0
# 高: 2.0
# 梯形的面積: 25.0
